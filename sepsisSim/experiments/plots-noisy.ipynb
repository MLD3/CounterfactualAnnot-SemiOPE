# %%
# ## Simulation parameters
exp_name = 'exp-FINAL'
eps = 0.10
eps_str = '0_1'

run_idx_length = 1_000
N_val = 1_000
runs = 50

# %%
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['Arial']
# %config InlineBackend.figure_formats = ['svg']

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from collections import defaultdict
import pickle
import itertools
import copy
import random
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from sklearn import metrics
import itertools

import joblib
from joblib import Parallel, delayed

# %%
from OPE_utils_new import (
    format_data_tensor,
    policy_eval_analytic_finite,
    OPE_IS_h,
    compute_behavior_policy_h,
)

# %%
def policy_eval_helper(π):
    V_H = policy_eval_analytic_finite(P.transpose((1,0,2)), R, π, gamma, H)
    Q_H = [(R + gamma * P.transpose((1,0,2)) @ V_H[h]) for h in range(1,H)] + [R]
    J = isd @ V_H[0]
    # Check recursive relationships
    assert len(Q_H) == H
    assert len(V_H) == H
    assert np.all(Q_H[-1] == R)
    assert np.all(np.sum(π * Q_H[-1], axis=1) == V_H[-1])
    assert np.all(R + gamma * P.transpose((1,0,2)) @ V_H[-1] == Q_H[-2])
    return V_H, Q_H, J

# %%
def iqm(x):
    return scipy.stats.trim_mean(x, proportiontocut=0.25, axis=None)

# %%
NSTEPS = H = 20   # max episode length in historical data # Horizon of the MDP
G_min = -1        # the minimum possible return
G_max =  1        # the maximum possible return
nS, nA = 1442, 8

PROB_DIAB = 0.2

# %%
# Ground truth MDP model
MDP_parameters = joblib.load('../data/MDP_parameters.joblib')
P = MDP_parameters['transition_matrix_absorbing'] # (A, S, S_next)
R = MDP_parameters['reward_matrix_absorbing_SA'] # (S, A)
nS, nA = R.shape
gamma = 0.99

# unif rand isd, mixture of diabetic state
isd = joblib.load('../data/modified_prior_initial_state_absorbing.joblib')
isd = (isd > 0).astype(float)
isd[:720] = isd[:720] / isd[:720].sum() * (1-PROB_DIAB)
isd[720:] = isd[720:] / isd[720:].sum() * (PROB_DIAB)

# %%
# Precomputed optimal policy
π_star = joblib.load('../data/π_star.joblib')

# %% [markdown]
# ## Policies

# %%
# vaso unif, mv abx optimal
π_unif = (np.tile(π_star.reshape((-1,2,2,2)).sum(axis=3, keepdims=True), (1,1,1,2)).reshape((-1, 8)) / 2)

# %% [markdown]
# ### Behavior policy

# %%
# vaso eps=0.5, mv abx optimal
π_beh = (np.tile(π_star.reshape((-1,2,2,2)).sum(axis=3, keepdims=True), (1,1,1,2)).reshape((-1, 8)) / 2)
π_beh[π_star == 1] = 1-eps
π_beh[π_beh == 0.5] = eps

# %%
V_H_beh, Q_H_beh, J_beh = policy_eval_helper(π_beh)
J_beh
# Out:
# 0.25038354793851164

# %% [markdown]
# ### Optimal policy

# %%
V_H_star, Q_H_star, J_star = policy_eval_helper(π_star)
J_star
# Out:
# 0.40877179296760224

# %% [markdown]
# ### flip action for x% states

# %%
def get_π_flip(pol_flip_seed, pol_flip_num):
    rng_flip = np.random.default_rng(pol_flip_seed)
    flip_states = rng_flip.choice(range(1440), pol_flip_num, replace=False)

    π_tmp = (np.tile(π_star.reshape((-1,2,2,2)).sum(axis=3, keepdims=True), (1,1,1,2)).reshape((-1, 8)) / 2)
    π_flip = π_tmp.copy()
    π_flip[π_tmp == 0.5] = 0
    π_flip[π_star == 1] = 1
    for s in flip_states:
        π_flip[s, π_tmp[s] == 0.5] = 1
        π_flip[s, π_star[s] == 1] = 0
    assert π_flip.sum(axis=1).mean() == 1
    return π_flip

# %%
πs_flip_list = []
for flip_num in [0, 50, 100, 200, 300, 400]:
    for flip_seed in [0, 42, 123, 424242, 10000]:
        if flip_num == 0 and flip_seed != 0: continue
        π_flip = get_π_flip(flip_seed, flip_num)
        πs_flip_list.append(π_flip)

# %%
v_list = []
for π_eval in tqdm(πs_flip_list):
    _, _, J_eval = policy_eval_helper(π_eval)
    v_list.append(J_eval)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 26/26 [00:16<00:00,  1.57it/s]

# %%
plt.plot(v_list, ls='none', marker='.')
plt.axhline(J_beh, c='k', ls='--', label='behavior', zorder=0)
plt.show()

# %% [markdown]
# ## Load results

# %%
df_results_0 = pd.read_csv(f'./results/{exp_name}-1/vaso_eps_{eps_str}-observed.csv')

# %%
dfs_results_orig_list = []
for flip_num in [0, 50, 100, 200, 300, 400]:
    for flip_seed in [0, 42, 123, 424242, 10000]:
        if flip_num == 0 and flip_seed != 0: continue
        pol_name = f'flip{flip_num}_seed{flip_seed}'
        df_results_ = pd.read_csv(f'./results/{exp_name}-1/vaso_eps_{eps_str}-{pol_name}-orig.csv')
        dfs_results_orig_list.append(df_results_)

# %%
dfs_results_annotEval_list = []
for flip_num in [0, 50, 100, 200, 300, 400]:
    for flip_seed in [0, 42, 123, 424242, 10000]:
        if flip_num == 0 and flip_seed != 0: continue
        pol_name = f'flip{flip_num}_seed{flip_seed}'
        df_results_ = pd.read_csv(f'./results/{exp_name}-2/vaso_eps_{eps_str}-{pol_name}-aug_step-annotEval.csv')
        dfs_results_annotEval_list.append(df_results_)

# %%
noise_list = list(np.arange(0.0, 1.1, 0.1).round(1))

# %%
dfs_results_annotEvalNoise_lists = []
for noise in noise_list:
    dfs_results_annotEvalNoise_list = []
    for flip_num in [0, 50, 100, 200, 300, 400]:
        for flip_seed in [0, 42, 123, 424242, 10000]:
            if flip_num == 0 and flip_seed != 0: continue
            pol_name = f'flip{flip_num}_seed{flip_seed}'
            df_results_ = pd.read_csv(f'./results/{exp_name}-3/vaso_eps_{eps_str}-{pol_name}-aug_step-annotEval-Noise_{noise}.csv')
            dfs_results_annotEvalNoise_list.append(df_results_)
    dfs_results_annotEvalNoise_lists.append(dfs_results_annotEvalNoise_list)

# %% [markdown]
# ## Plots

# %%
exp_idx = 13
π_eval = πs_flip_list[exp_idx]
J_eval = v_list[exp_idx]
df_results_orig = dfs_results_orig_list[exp_idx]
df_results_annotEval = dfs_results_annotEval_list[exp_idx]

# %%
df_results_annotEval_Noise = [dfs[exp_idx] for dfs in dfs_results_annotEvalNoise_lists]

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.axhline(J_beh, c='k', ls='--', label='behavior', zorder=0)
plt.scatter(N_val, J_beh, marker='o', s=40, c='k', alpha=1)
plt.axhline(J_eval, c='k', ls=':', label='true', zorder=0)
plt.scatter([N_val]*runs, df_results_0['IS_value'], 
            marker='o', s=10, c='k', alpha=0.25, ec='none')

for df, name, color in [
    [df_results_orig, 'original', 'tab:blue'],
    [df_results_annotEval, 'proposed', 'tab:green'],
    [df_results_annotEval_Noise[-1], 'proposed noise', 'tab:cyan'],
]:
    plt.plot(0,0, c=color, label=name)
    plt.scatter(df['ESS1'], df['IS_value'], marker='o', s=10, c=color, alpha=0.25, ec='none')
    plt.scatter(iqm(df['ESS1']), iqm(df['IS_value']), marker='o', s=40, c=color, alpha=0.8)
    plt.scatter(df['ESS1'], df['WIS_value'], marker='X', s=10, c=color, alpha=0.25, ec='none')
    plt.scatter(iqm(df['ESS1']), iqm(df['WIS_value']), marker='X', s=40, c=color, alpha=0.8)

plt.scatter(-100,0, c='gray', marker='o', label='IS')
plt.scatter(-100,0, c='gray', marker='X', label='WIS')
plt.xlabel('ESS')
plt.ylabel('OPE value')
# plt.ylim(0.1, 0.7)
plt.xlim(0, N_val*1.25)
plt.legend(bbox_to_anchor=(1.04, 1))
plt.show()

# %% [markdown]
# ## Metrics

# %%
def rmse(y1, y2):
    return np.sqrt(np.mean(np.square(y1-y2)))

# %%
def compute_confmat(J_eval, v_est_list):
    confmat = np.zeros((2,2))
    confmat[int(J_eval >= J_beh), 0] += (v_est_list < df_results_0['IS_value'].iloc[:len(v_est_list)]).sum()
    confmat[int(J_eval >= J_beh), 1] += (v_est_list >= df_results_0['IS_value'].iloc[:len(v_est_list)]).sum()
    return confmat

# %%
def compute_confmat_batch(v_list, v_est_list, v_beh):
    confmat = np.zeros((2,2))
    for J_eval, v_est in zip(v_list, v_est_list):
        confmat[int(J_eval >= J_beh), 0] += (v_est < v_beh).sum()
        confmat[int(J_eval >= J_beh), 1] += (v_est >= v_beh).sum()
    return confmat

# %%
orig_v_IS = []
orig_v_WIS = []
orig_v_ESS = []
for π_eval, df_results_ in zip(πs_flip_list, dfs_results_orig_list):
    orig_v_IS.append(df_results_['IS_value'])
    orig_v_WIS.append(df_results_['WIS_value'])
    orig_v_ESS.append(df_results_['ESS1'])

# %%
annotEval_v_IS = []
annotEval_v_WIS = []
annotEval_v_ESS = []
for π_eval, df_results_ in zip(πs_flip_list, dfs_results_annotEval_list):
    annotEval_v_IS.append(df_results_['IS_value'])
    annotEval_v_WIS.append(df_results_['WIS_value'])
    annotEval_v_ESS.append(df_results_['ESS1'])

# %%
orig_rmse_value = np.mean([rmse(l,v) for v,l in zip(v_list+v_list, orig_v_IS+orig_v_WIS)])
orig_spearman_corr = np.mean([scipy.stats.spearmanr(v_list+v_list, v_π_est_list).correlation for v_π_est_list in np.array(orig_v_IS+orig_v_WIS).T])

# %%
oracle_rmse_value = np.mean([rmse(l,v) for v,l in zip(v_list+v_list, annotEval_v_IS+annotEval_v_WIS)])
oracle_spearman_corr = np.mean([scipy.stats.spearmanr(v_list+v_list, v_π_est_list).correlation for v_π_est_list in np.array(annotEval_v_IS+annotEval_v_WIS).T])

# %%
all_results = []
for noise, df_results_lists in zip(noise_list, dfs_results_annotEvalNoise_lists):
    print('===', 'Noise', noise)
    v_IS = []
    v_WIS = []
    v_ESS = []
    for π_eval, df_results_ in zip(πs_flip_list, df_results_lists):
        v_IS.append(df_results_['IS_value'])
        v_WIS.append(df_results_['WIS_value'])
        v_ESS.append(df_results_['ESS1'])
    print('ESS:', np.mean(v_ESS), np.array(v_ESS).mean(axis=0).std())
    
    v_est_list = v_IS + v_WIS
    rmse_value = [rmse(l, np.array(v_list+v_list)) for l in np.array(v_est_list).T]
    print('RMSE: {:.3f}±{:.3f}'.format(np.mean(rmse_value).round(3), np.std(rmse_value).round(3)))
    
    spearman_corr = [scipy.stats.spearmanr(l, np.array(v_list+v_list)).correlation for l in np.array(v_est_list).T]
    print('Spearman: {:.3f}±{:.3f}'.format(np.mean(spearman_corr).round(3), np.std(spearman_corr).round(3)))
    
    confmats_ = [compute_confmat_batch(v_list+v_list, l, vb) for l,vb in zip(np.array(v_est_list).T, df_results_0['IS_value'])]
    confmat_sum = sum(confmats_)
    (accuracy, fpr, fnr) = (
        [(cm[0,0]+cm[1,1])/np.sum(cm) for cm in confmats_],
        [cm[0,1]/(cm[0,0]+cm[0,1]) for cm in confmats_], 
        [cm[1,0]/(cm[1,0]+cm[1,1]) for cm in confmats_],
    )
    print('Accuracy: {:.1%}±{:.1%} \t FPR: {:.1%}±{:.1%} \t FNR: {:.1%}±{:.1%}'.format(
        np.mean(accuracy), np.std(accuracy), 
        np.mean(fpr), np.std(fpr), 
        np.mean(fnr), np.std(fnr), 
    ))
    display(pd.DataFrame(
        (confmat_sum).astype(int), 
        index=['$$v(\pi_e) < v(\pi_b)$$', '$$v(\pi_e) \geq v(\pi_b)$$'],
        columns=['$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$', '$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$'],
    ).rename_axis(index='True Ranking', columns=f'{name} Predicted Ranking')\
            .style.background_gradient(cmap='Blues', vmin=0, vmax=1500))
    
    all_results.append({
        'spearman': spearman_corr,
        'rmse': rmse_value,
        'accuracy': accuracy,
        'fpr': fpr,
        'fnr': fnr
    })
# Out:
# === Noise 0.0
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.013±0.005
# Spearman: 0.995±0.003
# Accuracy: 95.7%±3.1% 	 FPR: 4.5%±6.9% 	 FNR: 4.2%±5.3%
# <style  type="text/css" >
# #T_15b02e96_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_15b02e96_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_15b02e96_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_15b02e96_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }</style><table id="T_15b02e96_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15b02e96_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15b02e96_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1050</td>
#                         <td id="T_15b02e96_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_15b02e96_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15b02e96_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >63</td>
#                         <td id="T_15b02e96_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1437</td>
#             </tr>
#     </tbody></table>
# === Noise 0.1
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.013±0.005
# Spearman: 0.995±0.003
# Accuracy: 95.7%±3.5% 	 FPR: 4.4%±7.5% 	 FNR: 4.3%±5.7%
# <style  type="text/css" >
# #T_15b903cc_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_15b903cc_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_15b903cc_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_15b903cc_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }</style><table id="T_15b903cc_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15b903cc_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15b903cc_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1052</td>
#                         <td id="T_15b903cc_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >48</td>
#             </tr>
#             <tr>
#                         <th id="T_15b903cc_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15b903cc_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >65</td>
#                         <td id="T_15b903cc_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1435</td>
#             </tr>
#     </tbody></table>
# === Noise 0.2
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.014±0.005
# Spearman: 0.994±0.002
# Accuracy: 95.3%±4.1% 	 FPR: 4.4%±7.9% 	 FNR: 4.9%±6.8%
# <style  type="text/css" >
# #T_15c1cc78_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_15c1cc78_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_15c1cc78_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_15c1cc78_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }</style><table id="T_15c1cc78_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15c1cc78_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15c1cc78_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1052</td>
#                         <td id="T_15c1cc78_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >48</td>
#             </tr>
#             <tr>
#                         <th id="T_15c1cc78_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15c1cc78_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >73</td>
#                         <td id="T_15c1cc78_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1427</td>
#             </tr>
#     </tbody></table>
# === Noise 0.3
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.015±0.005
# Spearman: 0.994±0.002
# Accuracy: 95.2%±4.5% 	 FPR: 4.7%±8.1% 	 FNR: 4.9%±7.5%
# <style  type="text/css" >
# #T_15caa5c8_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }#T_15caa5c8_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_15caa5c8_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_15caa5c8_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }</style><table id="T_15caa5c8_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15caa5c8_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15caa5c8_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1048</td>
#                         <td id="T_15caa5c8_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_15caa5c8_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15caa5c8_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >74</td>
#                         <td id="T_15caa5c8_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1426</td>
#             </tr>
#     </tbody></table>
# === Noise 0.4
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.016±0.006
# Spearman: 0.992±0.003
# Accuracy: 94.9%±4.6% 	 FPR: 4.5%±8.2% 	 FNR: 5.5%±8.0%
# <style  type="text/css" >
# #T_15d374b4_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_15d374b4_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_15d374b4_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_15d374b4_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }</style><table id="T_15d374b4_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15d374b4_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15d374b4_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1050</td>
#                         <td id="T_15d374b4_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_15d374b4_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15d374b4_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >82</td>
#                         <td id="T_15d374b4_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1418</td>
#             </tr>
#     </tbody></table>
# === Noise 0.5
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.018±0.006
# Spearman: 0.991±0.004
# Accuracy: 94.8%±4.8% 	 FPR: 4.5%±8.2% 	 FNR: 5.7%±8.3%
# <style  type="text/css" >
# #T_15dc3df6_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_15dc3df6_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_15dc3df6_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }#T_15dc3df6_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #083e81;
#             color:  #f1f1f1;
#         }</style><table id="T_15dc3df6_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15dc3df6_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15dc3df6_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1050</td>
#                         <td id="T_15dc3df6_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_15dc3df6_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15dc3df6_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >85</td>
#                         <td id="T_15dc3df6_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1415</td>
#             </tr>
#     </tbody></table>
# === Noise 0.6
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.020±0.007
# Spearman: 0.988±0.005
# Accuracy: 94.2%±5.1% 	 FPR: 4.9%±8.8% 	 FNR: 6.5%±8.9%
# <style  type="text/css" >
# #T_15e51f52_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }#T_15e51f52_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_15e51f52_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_15e51f52_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #084184;
#             color:  #f1f1f1;
#         }</style><table id="T_15e51f52_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15e51f52_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15e51f52_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1046</td>
#                         <td id="T_15e51f52_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >54</td>
#             </tr>
#             <tr>
#                         <th id="T_15e51f52_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15e51f52_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >98</td>
#                         <td id="T_15e51f52_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1402</td>
#             </tr>
#     </tbody></table>
# === Noise 0.7
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.022±0.008
# Spearman: 0.986±0.006
# Accuracy: 93.5%±5.4% 	 FPR: 5.2%±9.3% 	 FNR: 7.5%±9.8%
# <style  type="text/css" >
# #T_15eefb6c_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }#T_15eefb6c_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_15eefb6c_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_15eefb6c_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }</style><table id="T_15eefb6c_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15eefb6c_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15eefb6c_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1043</td>
#                         <td id="T_15eefb6c_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >57</td>
#             </tr>
#             <tr>
#                         <th id="T_15eefb6c_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15eefb6c_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >112</td>
#                         <td id="T_15eefb6c_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1388</td>
#             </tr>
#     </tbody></table>
# === Noise 0.8
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.024±0.008
# Spearman: 0.983±0.008
# Accuracy: 92.9%±5.7% 	 FPR: 5.7%±10.0% 	 FNR: 8.1%±10.3%
# <style  type="text/css" >
# #T_15f7d624_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #3181bd;
#             color:  #000000;
#         }#T_15f7d624_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_15f7d624_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_15f7d624_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }</style><table id="T_15f7d624_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15f7d624_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_15f7d624_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1037</td>
#                         <td id="T_15f7d624_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >63</td>
#             </tr>
#             <tr>
#                         <th id="T_15f7d624_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_15f7d624_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >122</td>
#                         <td id="T_15f7d624_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1378</td>
#             </tr>
#     </tbody></table>
# === Noise 0.9
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.027±0.009
# Spearman: 0.980±0.009
# Accuracy: 92.4%±5.7% 	 FPR: 6.5%±10.6% 	 FNR: 8.3%±10.5%
# <style  type="text/css" >
# #T_1600a9f2_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #3282be;
#             color:  #000000;
#         }#T_1600a9f2_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_1600a9f2_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }#T_1600a9f2_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }</style><table id="T_1600a9f2_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1600a9f2_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_1600a9f2_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1028</td>
#                         <td id="T_1600a9f2_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >72</td>
#             </tr>
#             <tr>
#                         <th id="T_1600a9f2_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_1600a9f2_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >125</td>
#                         <td id="T_1600a9f2_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1375</td>
#             </tr>
#     </tbody></table>
# === Noise 1.0
# ESS: 993.9926736346977 3.030694969543688
# RMSE: 0.029±0.010
# Spearman: 0.977±0.012
# Accuracy: 91.9%±5.6% 	 FPR: 6.7%±10.5% 	 FNR: 9.1%±10.6%
# <style  type="text/css" >
# #T_160970b4_e780_11ed_96dc_6309e7711524row0_col0{
#             background-color:  #3282be;
#             color:  #000000;
#         }#T_160970b4_e780_11ed_96dc_6309e7711524row0_col1{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_160970b4_e780_11ed_96dc_6309e7711524row1_col0{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_160970b4_e780_11ed_96dc_6309e7711524row1_col1{
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }</style><table id="T_160970b4_e780_11ed_96dc_6309e7711524" ><thead>    <tr>        <th class="index_name level0" >proposed noise Predicted Ranking</th>        <th class="col_heading level0 col0" >$$\hat{v}(\pi_e) < \hat{v}(\pi_b)$$</th>        <th class="col_heading level0 col1" >$$\hat{v}(\pi_e) \geq \hat{v}(\pi_b)$$</th>    </tr>    <tr>        <th class="index_name level0" >True Ranking</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_160970b4_e780_11ed_96dc_6309e7711524level0_row0" class="row_heading level0 row0" >$$v(\pi_e) < v(\pi_b)$$</th>
#                         <td id="T_160970b4_e780_11ed_96dc_6309e7711524row0_col0" class="data row0 col0" >1026</td>
#                         <td id="T_160970b4_e780_11ed_96dc_6309e7711524row0_col1" class="data row0 col1" >74</td>
#             </tr>
#             <tr>
#                         <th id="T_160970b4_e780_11ed_96dc_6309e7711524level0_row1" class="row_heading level0 row1" >$$v(\pi_e) \geq v(\pi_b)$$</th>
#                         <td id="T_160970b4_e780_11ed_96dc_6309e7711524row1_col0" class="data row1 col0" >136</td>
#                         <td id="T_160970b4_e780_11ed_96dc_6309e7711524row1_col1" class="data row1 col1" >1364</td>
#             </tr>
#     </tbody></table>

# %%
df_all_results = pd.DataFrame(all_results, index=noise_list)
df_all_results.index.name = 'noise'

# %%
df_all_results_median = df_all_results.applymap(np.median)
df_all_results_mean = df_all_results.applymap(np.mean)
df_all_results_std = df_all_results.applymap(np.std)

# %%
fig, ax = plt.subplots(3,1, sharex=True, figsize=(2.5,3))
df_all_results_mean['rmse'].plot(ls='-', lw=1, marker='s', ms=2, c='tab:blue', ax=ax[0])
df_all_results_mean['spearman'].plot(ls='-', lw=1, marker='s', ms=2, c='tab:blue', ax=ax[1])
df_all_results_mean['accuracy'].plot(ls='-', lw=1, marker='s', ms=2, c='tab:blue', ax=ax[2])
ax[0].fill_between(noise_list, 
                   df_all_results_mean['rmse']-df_all_results_std['rmse'], 
                   df_all_results_mean['rmse']+df_all_results_std['rmse'], fc='tab:blue', alpha=0.2,
                  )
ax[1].fill_between(noise_list, 
                   df_all_results_mean['spearman']-df_all_results_std['spearman'], 
                   df_all_results_mean['spearman']+df_all_results_std['spearman'], fc='tab:blue', alpha=0.2,
                  )
ax[2].fill_between(noise_list, 
                   df_all_results_mean['accuracy']-df_all_results_std['accuracy'], 
                   df_all_results_mean['accuracy']+df_all_results_std['accuracy'], fc='tab:blue', alpha=0.2,
                  )
ax[0].plot(0, oracle_rmse_value, marker='*', c='k')
ax[1].plot(0, oracle_spearman_corr, marker='*', c='k')
ax[2].plot(0, 0.957, marker='*', c='k')
ax[0].axhline(orig_rmse_value, c='gray', ls=(0,(0.5,0.5)), lw=1)
ax[1].axhline(orig_spearman_corr, c='gray', ls=(0,(0.5,0.5)), lw=1)
ax[2].axhline(0.765, c='gray', ls=(0,(0.5,0.5)), lw=1)
ax[0].set_ylabel('RMSE')
ax[1].set_ylabel('Spearman\nCorr.')
ax[2].set_ylabel('Bin. Class.\nAccuracy')
ax[0].set_ylim(0, 0.15)
ax[1].set_ylim(0.45, 1.05)
ax[2].set_ylim(0.7, 1.05)
plt.xlabel('Std of annotation noise')
fig.align_labels()
# plt.figlegend(
#     [matplotlib.lines.Line2D([], [], c='gray', ls=':'), 
#      matplotlib.lines.Line2D([], [], c='k', marker='*', linestyle='none'),
#      matplotlib.lines.Line2D([], [], c='tab:blue'), 
#      ],
#     ['baseline', 'ideal setting', 'proposed', ],
#     loc='center', bbox_to_anchor=(0.5,1.0),
#     ncol=2, handlelength=1.333, handletextpad=0.6, columnspacing=1,
# )
plt.savefig('fig/annotation_noisy.pdf', bbox_inches='tight')
plt.show()
